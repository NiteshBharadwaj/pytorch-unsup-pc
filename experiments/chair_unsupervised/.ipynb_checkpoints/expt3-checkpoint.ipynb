# %%
import os
import sys

import numpy as np
import scipy.io

import sys
sys.path.append("../../dpc/")
from util.point_cloud import point_cloud_distance
from util.simple_dataset import Dataset3D
from util.app_config import config as app_config
from util.tools import partition_range, to_np_object
from util.quaternion import quaternion_rotate
from util.euler import ypr_from_campos

import torch
from torch.utils.tensorboard import SummaryWriter
from models import model_pc_to as model_pc
from util.system import setup_environment
from run.ShapeRecords import ShapeRecords

import pickle
import pdb

# %%
def compute_distance(cfg, source_np, target_np):
    """
    compute projection from source to target
    """
    num_parts = cfg.pc_eval_chamfer_num_parts
    partition = partition_range(source_np.shape[0], num_parts)
    min_dist_np = np.zeros((0,))
    idx_np = np.zeros((0,))
    source_pc = torch.from_numpy(source_np).cuda()
    target_pc = torch.from_numpy(target_np).cuda()
    for k in range(num_parts):
        r = partition[k, :]
        src = source_pc[r[0]:r[1]]
        _, min_dist, min_idx = point_cloud_distance(src, target_pc)
        min_dist_0_np = min_dist.cpu().numpy()
        idx_0_np = min_idx.cpu().numpy()
        min_dist_np = np.concatenate((min_dist_np, min_dist_0_np), axis=0)
        idx_np = np.concatenate((idx_np, idx_0_np), axis=0)

    return min_dist_np, idx_np

# %%
def get_group(pos,divs):
    scale = divs/2
    yaw, pitch, roll = ypr_from_campos(pos[0], pos[1], pos[2])
    yaw = yaw + np.pi
    # get everything from 0 to 2*pi
    yaw = yaw%(2*np.pi)+0.00000001
    pitch = pitch%(2*np.pi)+0.00000001
    roll = roll%(2*np.pi) + 0.00000001
    
    q1 = np.ceil(scale*yaw/np.pi)-1
    q2 = np.ceil(scale*pitch/np.pi)-1
    q3 = np.ceil(scale*roll/np.pi)-1
    
    return q1*np.square(divs)+q2*divs+q3

# %%
    cfg = app_config

    setup_environment(cfg)
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    train_dir = cfg.checkpoint_dir

    split_name = "eval"
    dataset_folder = cfg.inp_dir
    
    dataset = ShapeRecords(dataset_folder, cfg, 'test')
    dataset_loader = torch.utils.data.DataLoader(dataset,
                                                 batch_size=cfg.batch_size, shuffle=cfg.shuffle_dataset,
                                                 num_workers=4, drop_last=True)
# Out:
# Initialized dataset test with size 1355

# %%
    divs = 8
    cfg = app_config
    exp_dir = cfg.checkpoint_dir
    num_views = cfg.num_views
    eval_unsup = cfg.eval_unsupervised_shape
    dataset_folder = cfg.inp_dir

    gt_dir = os.path.join(cfg.gt_pc_dir, cfg.synth_set)

    save_pred_name = "{}_{}".format(cfg.save_predictions_dir, cfg.eval_split)
    save_dir = os.path.join(exp_dir, cfg.save_predictions_dir)

    if eval_unsup:
        reference_rotation = scipy.io.loadmat("{}/final_reference_rotation.mat".format(exp_dir))["rotation"]

    dataset = ShapeRecords(dataset_folder, cfg, 'test')

    if cfg.models_list:
        model_names = parse_lines(cfg.models_list)
    else:
        model_names = dataset.file_names
    num_models = len(model_names)

    # making groups for samples and views according to 8 groups of yaw, pitch, roll
    all_images = np.zeros((0,128,128,3))
    chamfer_all = np.zeros((0,2))
    groups = []

    for k in range(150):
        sample = dataset.__getitem__(k)

        print("{}/{}".format(k, num_models))
        print(model_names[k])

        gt_filename = "{}/{}.mat".format(gt_dir, model_names[k]).replace('_features.p', '')
        mat_filename = "{}/{}_pc.pkl".format(save_dir, model_names[k])

        if not os.path.isfile(gt_filename) or not os.path.isfile(mat_filename):
            continue

        with open(mat_filename, 'rb') as handle:
            data = pickle.load(handle)
        all_pcs = np.squeeze(data["points"])
        if "num_points" in data:
            all_pcs_nums = np.squeeze(data["num_points"])
            has_number = True
        else:
            has_number = False
        obj = scipy.io.loadmat(gt_filename)
        Vgt = obj["points"]

        for i in range(num_views):
            chamfer_dists_current = np.zeros((2), dtype=np.float64)

            pred = all_pcs[i, :, :]
            if has_number:
                pred = pred[0:all_pcs_nums[i], :]

            if eval_unsup:
                pred = np.expand_dims(pred, 0)
                pred = quaternion_rotate(torch.from_numpy(pred).cuda(),
                                         torch.from_numpy(reference_rotation).cuda()).cpu().numpy()
                pred = np.squeeze(pred)

            pred_to_gt, idx_np = compute_distance(cfg, pred, Vgt)
            gt_to_pred, _ = compute_distance(cfg, Vgt, pred)
            chamfer_dists_current[0] = np.mean(pred_to_gt)
            chamfer_dists_current[1] = np.mean(gt_to_pred)

            is_nan = np.isnan(pred_to_gt)
            assert (not np.any(is_nan))

            campos = sample['cam_pos'][i]
            images = sample['image'][i].transpose(1,2,0)
            g = get_group(campos, divs)
            groups.append(g)

            all_images = np.concatenate((all_images, np.expand_dims(images,0)))
            chamfer_all = np.concatenate((chamfer_all, np.expand_dims(chamfer_dists_current, 0)))
            #print(i, ":", chamfer_dists_current)
    groups = np.array(groups)
        # current_mean = np.mean(chamfer_dists_current, 0)
        # print("total:", current_mean)
# Out:
# Initialized dataset test with size 1355
# 1/1355
# b29d302a87099d924d8777315ca26f7d_features.p
# 2/1355
# 7f820a5aef9899d5e2953fd13c76ba9_features.p
# 3/1355
# 1f857fce279b761435fbe95f496199e_features.p
# 4/1355
# 736589cbc46fe6b059f8e31ca87c470e_features.p
# 5/1355
# 9efb86c07170d7e897ec301178d1c7e_features.p
# 6/1355
# faa6255bb4de99d90606ee5fb3c339a_features.p
# 7/1355
# 68747a56aba6ee318677364bd64735c4_features.p
# 8/1355
# 1ee92a9d78cccbda98d2e7dbe701ca48_features.p
# 9/1355
# 233cf8ec4019005ceaf288f952624966_features.p
# 10/1355
# 9d2cf09ddd9a05fa1f8b303c0da5108d_features.p
# 11/1355
# 2c5e32bb738a5306e27790b0ec8671f7_features.p
# 12/1355
# 48f0c9b02587b5a8ea0588dd0d874b1e_features.p
# 13/1355
# ad023095f1868d3019fb4103277a6b93_features.p
# 14/1355
# 5f355e2a9fa2f0db4b3c42e318f3affc_features.p
# 15/1355
# dbf235de67b39c2d25e2408bd7177733_features.p
# 16/1355
# ce8f3a0c0c0bb0b9b20716e5484f7807_features.p
# 17/1355
# 6d3081bce72521e088e9c1fdc7b9075c_features.p
# 18/1355
# 50016cf5a426bd63f9d384ecdcc090b1_features.p
# 19/1355
# 484a7d924c952e51af7c7ad2549a1b15_features.p
chamfer_cleaned = {}
for k in images_dict.keys():
    if not images_dict[k].any():
        print("No objects grouped under group",k)
    else:
        images_dict_cleaned[k] = images_dict[k]
        chamfer_cleaned[k] = chamfer_dict[k]
chamfer_dict = chamfer_cleaned
images_dict = images_dict_cleaned
for key in chamfer_dict:
        print(key, np.mean(chamfer_dict[key],0)*100)
# Out:
# No objects grouped under group 1
# No objects grouped under group 2
# No objects grouped under group 3
# No objects grouped under group 4
# No objects grouped under group 5
# No objects grouped under group 6
# No objects grouped under group 7
# No objects grouped under group 8
# No objects grouped under group 9
# No objects grouped under group 10
# No objects grouped under group 11
# No objects grouped under group 12
# No objects grouped under group 13
# No objects grouped under group 14
# No objects grouped under group 15
# No objects grouped under group 16
# No objects grouped under group 17
# No objects grouped under group 18
# No objects grouped under group 19
# No objects grouped under group 20
# No objects grouped under group 21
# No objects grouped under group 22
# No objects grouped under group 23
# No objects grouped under group 24
# No objects grouped under group 25
# No objects grouped under group 26
# No objects grouped under group 27
# No objects grouped under group 28
# No objects grouped under group 29
# No objects grouped under group 30
# No objects grouped under group 31
# No objects grouped under group 32
# No objects grouped under group 33
# No objects grouped under group 34
# No objects grouped under group 35
# No objects grouped under group 36
# No objects grouped under group 37
# No objects grouped under group 38
# No objects grouped under group 39
# No objects grouped under group 40
# No objects grouped under group 41
# No objects grouped under group 42
# No objects grouped under group 43
# No objects grouped under group 44
# No objects grouped under group 45
# No objects grouped under group 46
# No objects grouped under group 47
# No objects grouped under group 48
# No objects grouped under group 49
# No objects grouped under group 50
# No objects grouped under group 51
# No objects grouped under group 52
# No objects grouped under group 53
# No objects grouped under group 54
# No objects grouped under group 55
# No objects grouped under group 57
# No objects grouped under group 58
# No objects grouped under group 59
# No objects grouped under group 60
# No objects grouped under group 61
# No objects grouped under group 62
# No objects grouped under group 63
# No objects grouped under group 65
# No objects grouped under group 66
# No objects grouped under group 67
# No objects grouped under group 68
# No objects grouped under group 69
# No objects grouped under group 70
# No objects grouped under group 71
# No objects grouped under group 72
# No objects grouped under group 73
# No objects grouped under group 74
# No objects grouped under group 75
# No objects grouped under group 76
# No objects grouped under group 77
# No objects grouped under group 78
# No objects grouped under group 79
# No objects grouped under group 80
# No objects grouped under group 81
# No objects grouped under group 82
# No objects grouped under group 83
# No objects grouped under group 84
# No objects grouped under group 85
# No objects grouped under group 86
# No objects grouped under group 87
# No objects grouped under group 88
# No objects grouped under group 89
# No objects grouped under group 90
# No objects grouped under group 91
# No objects grouped under group 92
# No objects grouped under group 93
# No objects grouped under group 94
# No objects grouped under group 95
# No objects grouped under group 96
# No objects grouped under group 97
# No objects grouped under group 98
# No objects grouped under group 99
# No objects grouped under group 100
# No objects grouped under group 101
# No objects grouped under group 102
# No objects grouped under group 103
# No objects grouped under group 104
# No objects grouped under group 105
# No objects grouped under group 106
# No objects grouped under group 107
# No objects grouped under group 108
# No objects grouped under group 109
# No objects grouped under group 110
# No objects grouped under group 111
# No objects grouped under group 112
# No objects grouped under group 113
# No objects grouped under group 114
# No objects grouped under group 115
# No objects grouped under group 116
# No objects grouped under group 117
# No objects grouped under group 118
# No objects grouped under group 119
# No objects grouped under group 121
# No objects grouped under group 122
# No objects grouped under group 123
# No objects grouped under group 124
# No objects grouped under group 125
# No objects grouped under group 126
# No objects grouped under group 127
# No objects grouped under group 129
# No objects grouped under group 130
# No objects grouped under group 131
# No objects grouped under group 132
# No objects grouped under group 133
# No objects grouped under group 134
# No objects grouped under group 135
# No objects grouped under group 136
# No objects grouped under group 137
# No objects grouped under group 138
# No objects grouped under group 139
# No objects grouped under group 140
# No objects grouped under group 141
# No objects grouped under group 142
# No objects grouped under group 143
# No objects grouped under group 144
# No objects grouped under group 145
# No objects grouped under group 146
# No objects grouped under group 147
# No objects grouped under group 148
# No objects grouped under group 149
# No objects grouped under group 150
# No objects grouped under group 151
# No objects grouped under group 152
# No objects grouped under group 153
# No objects grouped under group 154
# No objects grouped under group 155
# No objects grouped under group 156
# No objects grouped under group 157
# No objects grouped under group 158
# No objects grouped under group 159
# No objects grouped under group 160
# No objects grouped under group 161
# No objects grouped under group 162
# No objects grouped under group 163
# No objects grouped under group 164
# No objects grouped under group 165
# No objects grouped under group 166
# No objects grouped under group 167
# No objects grouped under group 168
# No objects grouped under group 169
# No objects grouped under group 170
# No objects grouped under group 171
# No objects grouped under group 172
# No objects grouped under group 173
# No objects grouped under group 174
# No objects grouped under group 175
# No objects grouped under group 176
# No objects grouped under group 177
# No objects grouped under group 178
# No objects grouped under group 179
# No objects grouped under group 180
# No objects grouped under group 181
# No objects grouped under group 182
# No objects grouped under group 183
# No objects grouped under group 185
# No objects grouped under group 186
# No objects grouped under group 187
# No objects grouped under group 188
# No objects grouped under group 189
# No objects grouped under group 190
# No objects grouped under group 191
# No objects grouped under group 193
# No objects grouped under group 194
# No objects grouped under group 195
# No objects grouped under group 196
# No objects grouped under group 197
# No objects grouped under group 198
# No objects grouped under group 199
# No objects grouped under group 200
# No objects grouped under group 201
# No objects grouped under group 202
# No objects grouped under group 203
# No objects grouped under group 204
# No objects grouped under group 205
# No objects grouped under group 206
# No objects grouped under group 207
# No objects grouped under group 208
# No objects grouped under group 209
# No objects grouped under group 210
# No objects grouped under group 211
# No objects grouped under group 212
# No objects grouped under group 213
# No objects grouped under group 214
# No objects grouped under group 215
# No objects grouped under group 216
# No objects grouped under group 217
# No objects grouped under group 218
# No objects grouped under group 219
# No objects grouped under group 220
# No objects grouped under group 221
# No objects grouped under group 222
# No objects grouped under group 223
# No objects grouped under group 224
# No objects grouped under group 225
# No objects grouped under group 226
# No objects grouped under group 227
# No objects grouped under group 228
# No objects grouped under group 229
# No objects grouped under group 230
# No objects grouped under group 231
# No objects grouped under group 232
# No objects grouped under group 233
# No objects grouped under group 234
# No objects grouped under group 235
# No objects grouped under group 236
# No objects grouped under group 237
# No objects grouped under group 238
# No objects grouped under group 239
# No objects grouped under group 240
# No objects grouped under group 241
# No objects grouped under group 242
# No objects grouped under group 243
# No objects grouped under group 244
# No objects grouped under group 245
# No objects grouped under group 246
# No objects grouped under group 247
# No objects grouped under group 249
# No objects grouped under group 250
# No objects grouped under group 251
# No objects grouped under group 252
# No objects grouped under group 253
# No objects grouped under group 254
# No objects grouped under group 255
# No objects grouped under group 257
# No objects grouped under group 258
# No objects grouped under group 259
# No objects grouped under group 260
# No objects grouped under group 261
# No objects grouped under group 262
# No objects grouped under group 263
# No objects grouped under group 264
# No objects grouped under group 265
# No objects grouped under group 266
# No objects grouped under group 267
# No objects grouped under group 268
# No objects grouped under group 269
# No objects grouped under group 270
# No objects grouped under group 271
# No objects grouped under group 272
# No objects grouped under group 273
# No objects grouped under group 274
# No objects grouped under group 275
# No objects grouped under group 276
# No objects grouped under group 277
# No objects grouped under group 278
# No objects grouped under group 279
# No objects grouped under group 280
# No objects grouped under group 281
# No objects grouped under group 282
# No objects grouped under group 283
# No objects grouped under group 284
# No objects grouped under group 285
# No objects grouped under group 286
# No objects grouped under group 287
# No objects grouped under group 288
# No objects grouped under group 289
# No objects grouped under group 290
# No objects grouped under group 291
# No objects grouped under group 292
# No objects grouped under group 293
# No objects grouped under group 294
# No objects grouped under group 295
# No objects grouped under group 296
# No objects grouped under group 297
# No objects grouped under group 298
# No objects grouped under group 299
# No objects grouped under group 300
# No objects grouped under group 301
# No objects grouped under group 302
# No objects grouped under group 303
# No objects grouped under group 304
# No objects grouped under group 305
# No objects grouped under group 306
# No objects grouped under group 307
# No objects grouped under group 308
# No objects grouped under group 309
# No objects grouped under group 310
# No objects grouped under group 311
# No objects grouped under group 313
# No objects grouped under group 314
# No objects grouped under group 315
# No objects grouped under group 316
# No objects grouped under group 317
# No objects grouped under group 318
# No objects grouped under group 319
# No objects grouped under group 321
# No objects grouped under group 322
# No objects grouped under group 323
# No objects grouped under group 324
# No objects grouped under group 325
# No objects grouped under group 326
# No objects grouped under group 327
# No objects grouped under group 328
# No objects grouped under group 329
# No objects grouped under group 330
# No objects grouped under group 331
# No objects grouped under group 332
# No objects grouped under group 333
# No objects grouped under group 334
# No objects grouped under group 335
# No objects grouped under group 336
# No objects grouped under group 337
# No objects grouped under group 338
# No objects grouped under group 339
# No objects grouped under group 340
# No objects grouped under group 341
# No objects grouped under group 342
# No objects grouped under group 343
# No objects grouped under group 344
# No objects grouped under group 345
# No objects grouped under group 346
# No objects grouped under group 347
# No objects grouped under group 348
# No objects grouped under group 349
# No objects grouped under group 350
# No objects grouped under group 351
# No objects grouped under group 352
# No objects grouped under group 353
# No objects grouped under group 354
# No objects grouped under group 355
# No objects grouped under group 356
# No objects grouped under group 357
# No objects grouped under group 358
# No objects grouped under group 359
# No objects grouped under group 360
# No objects grouped under group 361
# No objects grouped under group 362
# No objects grouped under group 363
# No objects grouped under group 364
# No objects grouped under group 365
# No objects grouped under group 366
# No objects grouped under group 367
# No objects grouped under group 368
# No objects grouped under group 369
# No objects grouped under group 370
# No objects grouped under group 371
# No objects grouped under group 372
# No objects grouped under group 373
# No objects grouped under group 374
# No objects grouped under group 375
# No objects grouped under group 377
# No objects grouped under group 378
# No objects grouped under group 379
# No objects grouped under group 380
# No objects grouped under group 381
# No objects grouped under group 382
# No objects grouped under group 383
# No objects grouped under group 385
# No objects grouped under group 386
# No objects grouped under group 387
# No objects grouped under group 388
# No objects grouped under group 389
# No objects grouped under group 390
# No objects grouped under group 391
# No objects grouped under group 392
# No objects grouped under group 393
# No objects grouped under group 394
# No objects grouped under group 395
# No objects grouped under group 396
# No objects grouped under group 397
# No objects grouped under group 398
# No objects grouped under group 399
# No objects grouped under group 400
# No objects grouped under group 401
# No objects grouped under group 402
# No objects grouped under group 403
# No objects grouped under group 404
# No objects grouped under group 405
# No objects grouped under group 406
# No objects grouped under group 407
# No objects grouped under group 408
# No objects grouped under group 409
# No objects grouped under group 410
# No objects grouped under group 411
# No objects grouped under group 412
# No objects grouped under group 413
# No objects grouped under group 414
# No objects grouped under group 415
# No objects grouped under group 416
# No objects grouped under group 417
# No objects grouped under group 418
# No objects grouped under group 419
# No objects grouped under group 420
# No objects grouped under group 421
# No objects grouped under group 422
# No objects grouped under group 423
# No objects grouped under group 424
# No objects grouped under group 425
# No objects grouped under group 426
# No objects grouped under group 427
# No objects grouped under group 428
# No objects grouped under group 429
# No objects grouped under group 430
# No objects grouped under group 431
# No objects grouped under group 432
# No objects grouped under group 433
# No objects grouped under group 434
# No objects grouped under group 435
# No objects grouped under group 436
# No objects grouped under group 437
# No objects grouped under group 438
# No objects grouped under group 439
# No objects grouped under group 441
# No objects grouped under group 442
# No objects grouped under group 443
# No objects grouped under group 444
# No objects grouped under group 445
# No objects grouped under group 446
# No objects grouped under group 447
# No objects grouped under group 449
# No objects grouped under group 450
# No objects grouped under group 451
# No objects grouped under group 452
# No objects grouped under group 453
# No objects grouped under group 454
# No objects grouped under group 455
# No objects grouped under group 456
# No objects grouped under group 457
# No objects grouped under group 458
# No objects grouped under group 459
# No objects grouped under group 460
# No objects grouped under group 461
# No objects grouped under group 462
# No objects grouped under group 463
# No objects grouped under group 464
# No objects grouped under group 465
# No objects grouped under group 466
# No objects grouped under group 467
# No objects grouped under group 468
# No objects grouped under group 469
# No objects grouped under group 470
# No objects grouped under group 471
# No objects grouped under group 472
# No objects grouped under group 473
# No objects grouped under group 474
# No objects grouped under group 475
# No objects grouped under group 476
# No objects grouped under group 477
# No objects grouped under group 478
# No objects grouped under group 479
# No objects grouped under group 480
# No objects grouped under group 481
# No objects grouped under group 482
# No objects grouped under group 483
# No objects grouped under group 484
# No objects grouped under group 485
# No objects grouped under group 486
# No objects grouped under group 487
# No objects grouped under group 488
# No objects grouped under group 489
# No objects grouped under group 490
# No objects grouped under group 491
# No objects grouped under group 492
# No objects grouped under group 493
# No objects grouped under group 494
# No objects grouped under group 495
# No objects grouped under group 496
# No objects grouped under group 497
# No objects grouped under group 498
# No objects grouped under group 499
# No objects grouped under group 500
# No objects grouped under group 501
# No objects grouped under group 502
# No objects grouped under group 503
# No objects grouped under group 505
# No objects grouped under group 506
# No objects grouped under group 507
# No objects grouped under group 508
# No objects grouped under group 509
# No objects grouped under group 510
# No objects grouped under group 511
# 0 [3.67965932 3.74436101]
# 56 [4.04788786 3.54322798]
# 64 [4.17356224 4.02125638]
# 120 [4.1181161  3.84057099]
# 128 [3.85570852 3.79368907]
# 184 [4.18138464 4.95493711]
# 192 [3.78130229 3.74523914]
# 248 [3.57687134 3.99775344]
# 256 [3.73974882 3.61498598]
# 312 [3.61604895 3.89114215]
# 320 [3.8285961  3.55960339]
# 376 [3.32226305 3.64716062]
# 384 [3.23018247 3.13607328]
# 440 [4.26464515 4.90146222]
# 448 [4.54403559 4.08022421]
# 504 [3.31328333 3.49582401]

# %% [markdown]
# ### Visualizing Groups

# %%
import matplotlib.pyplot as plt
import random
def display_nn_images(images, n, displ_str=None):
    samples = random.sample(range(0,images.shape[0]), min(n*n,images.shape[0]))
    f, axarr = plt.subplots(n,n)
    sample_idx = 0
    for i in range(n):
        for j in range(n):
            if sample_idx==len(samples):
                break
            axarr[i,j].imshow(images[samples[sample_idx]])
            sample_idx+=1
    plt.show()
    if displ_str is not None:
        print(displ_str)

# %%
display_nn_images(all_images,5)

# %%
disp1_close = []
for k in images_dict:
    displ_str = 'Group {} Chamfer: {}'.format(k,np.mean(chamfer_dict[k],0)*100)
    print(images_dict[k].shape[0])
    display_nn_images(images_dict[k],5, displ_str)

# %% [markdown]
# ### PCA of all images

# %%
from sklearn.decomposition import PCA

# %%
images_val = all_images.reshape(all_images.shape[0],-1)
pca = PCA(50)
pca_image = pca.fit_transform(images_val)
pca_image = pca_image.reshape(-1,50)
print('Explained variance {}'.format(pca.explained_variance_ratio_.sum()))
all_images_pca = pca_image
# Out:
# Explained variance 0.760369094960837

# %%
images_pca_dict = {}
for k in images_dict:
    print("Key:",k)
    images_val = images_dict[k].reshape(images_dict[k].shape[0],-1)
    pca = PCA(32)
    pca_image = pca.fit_transform(images_val)
    pca_image = pca_image.reshape(-1,32)
    print('Explained variance {}'.format(pca.explained_variance_ratio_.sum()))
    images_pca_dict[k] = pca_image
# Out:
# Key: 0
# Explained variance 0.9164257887107831
# Key: 56
# Explained variance 0.9955809130887703
# Key: 64
# Explained variance 0.9142746724018812
# Key: 120
# Explained variance 0.9927364085397776
# Key: 128
# Explained variance 0.9103884549772744
# Key: 184
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-fee51b4c7ce0> in <module>
#       4     images_val = images_dict[k].reshape(images_dict[k].shape[0],-1)
#       5     pca = PCA(32)
# ----> 6     pca_image = pca.fit_transform(images_val)
#       7     pca_image = pca_image.reshape(-1,32)
#       8     print('Explained variance {}'.format(pca.explained_variance_ratio_.sum()))
#
# /opt/conda/lib/python3.7/site-packages/sklearn/decomposition/pca.py in fit_transform(self, X, y)
#     358
#     359         """
# --> 360         U, S, V = self._fit(X)
#     361         U = U[:, :self.n_components_]
#     362
#
# /opt/conda/lib/python3.7/site-packages/sklearn/decomposition/pca.py in _fit(self, X)
#     405         # Call different fits for either full or truncated SVD
#     406         if self._fit_svd_solver == 'full':
# --> 407             return self._fit_full(X, n_components)
#     408         elif self._fit_svd_solver in ['arpack', 'randomized']:
#     409             return self._fit_truncated(X, n_components, self._fit_svd_solver)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/decomposition/pca.py in _fit_full(self, X, n_components)
#     424                              "min(n_samples, n_features)=%r with "
#     425                              "svd_solver='full'"
# --> 426                              % (n_components, min(n_samples, n_features)))
#     427         elif n_components >= 1:
#     428             if not isinstance(n_components, (numbers.Integral, np.integer)):
#
# ValueError: n_components=32 must be between 0 and min(n_samples, n_features)=30 with svd_solver='full'

# %%
from sklearn.cluster import KMeans
n_clusters = 5

# %%
kmeans_all = KMeans(n_clusters=n_clusters,init='k-means++',random_state=0).fit(all_images_pca)

# %%
kmeans_dict = {}
for k in images_pca_dict:
    kmeans_dict[k] = KMeans(n_clusters=n_clusters,init='k-means++',random_state=0).fit(images_pca_dict[k])

# %%
def chamfer_kmeans(kmeans, images_, chamfers_,groups_, n_cl,prepend='',n_displ=5):
    labels = kmeans.labels_
    for i in range(n_cl):
        mask = labels==i
        chamfers = chamfers_[mask]
        images = images_[mask]
        groups = groups_[mask]
        displ_str = prepend+'Chamfer Cluster {}: {}'.format(i,np.mean(chamfers,0)*100)
        print(images.shape)
        display_nn_images(images,n_displ, displ_str)
        uni_groups = np.unique(groups)
        for g in uni_groups:
            mask2 = groups==g
            images_g = images[mask2]
            chamfers_g = chamfers[mask2]
            displ_str = prepend+' Chamfer Cluster {}, Group {}: {}'.format(i,g,np.mean(chamfers_g,0)*100)
            display_nn_images(images_g,n_displ-2, displ_str)


chamfer_kmeans(kmeans_all, all_images, chamfer_all,groups,n_clusters)
# Out:
# [248. 384. 320. 256. 312.   0.   0. 384. 192. 384. 312. 128.  64. 448.
#  184. 384.  64. 440.   0. 248. 312. 192. 504.  64. 384. 248. 312. 376.
#  184. 376. 384. 440. 312. 184. 256. 376.   0. 320.  64. 448.  64. 256.
#  320. 384. 448.  64. 504. 312.  64. 256. 440. 120.   0. 320.   0. 448.
#  320.   0. 384. 384. 120. 120.  64. 320. 504. 256. 384. 256.  64. 128.
#  192.   0. 184. 384. 448. 384. 384. 448. 384. 128. 192. 248. 120. 184.
#  448. 384. 256. 120. 440. 192.  56.   0. 256. 448. 448. 128. 192. 128.
#    0. 184. 448. 384. 312. 320. 440. 448. 504. 128. 192. 448. 448. 384.
#  504. 128. 256. 184. 128. 448. 384. 192. 256. 376. 192. 192.   0. 504.
#  384.  64. 448. 248.   0.   0. 248. 320. 192.  64. 128. 192.  64. 384.
#  440. 312. 448. 192.  64. 376. 128. 320. 320. 192.  56. 384. 384. 440.
#  120. 192. 256. 192. 184.  64. 448. 312. 192. 320. 312. 448. 184. 192.
#  312. 312. 320.   0.  64.  64. 128. 192. 192. 192.   0. 184. 320. 312.
#  384.   0. 504. 376.   0. 440. 128.   0. 312.  64. 120. 128.  64.   0.
#  248. 320. 192. 192.  64. 248. 384. 384.   0.  64.   0. 312. 192. 312.
#  384. 320. 504. 192. 312. 440.   0. 384. 184. 256. 320. 184. 128. 320.
#  248. 320. 384. 448.   0. 120. 376. 256. 312. 320. 128. 384. 128.  56.
#  192. 256. 184. 448. 120.  64. 384. 248.   0.  56. 248. 128. 128. 440.
#  128. 504. 192. 120. 192. 192. 128. 448. 184. 320. 256. 128. 256. 320.

# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-79-a25fc29e72d9> in <module>
#      18
#      19 print(groups)
# ---> 20 chamfer_kmeans(kmeans_all, all_images, chamfer_all,groups,n_clusters)
#      21
#
# <ipython-input-79-a25fc29e72d9> in chamfer_kmeans(kmeans, images_, chamfers_, groups_, n_cl, prepend, n_displ)
#       5         chamfers = chamfers_[mask]
#       6         images = images_[mask]
# ----> 7         groups = groups[mask]
#       8         displ_str = prepend+'Chamfer Cluster {}: {}'.format(i,np.mean(chamfers,0)*100)
#       9         print(images.shape)
#
# UnboundLocalError: local variable 'groups' referenced before assignment

# %%
for k in kmeans_dict:
    chamfer_kmeans(kmeans_dict[k], images_dict[k], chamfer_dict[k],n_clusters,'Group {}: '.format(k),n_displ=3)
# Out:
# (16, 128, 128, 3)
# Group 0: Chamfer Cluster 0: [4.66581687 5.5665843 ]
# (16, 128, 128, 3)
# Group 0: Chamfer Cluster 1: [2.19861005 2.09527419]
# (23, 128, 128, 3)
# Group 0: Chamfer Cluster 2: [4.00697012 3.79521249]
# (1, 128, 128, 3)
# Group 0: Chamfer Cluster 3: [2.1817838  1.81398769]
# (4, 128, 128, 3)
# Group 0: Chamfer Cluster 4: [4.15165795 3.24201244]
# (4, 128, 128, 3)
# Group 56: Chamfer Cluster 0: [1.78826575 2.26439517]
# (8, 128, 128, 3)
# Group 56: Chamfer Cluster 1: [3.92340998 2.82751715]
# (9, 128, 128, 3)
# Group 56: Chamfer Cluster 2: [7.17947129 6.96506232]
# (5, 128, 128, 3)
# Group 56: Chamfer Cluster 3: [2.5394335  1.98742345]
# (9, 128, 128, 3)
# Group 56: Chamfer Cluster 4: [2.86925815 2.19028702]
# (13, 128, 128, 3)
# Group 64: Chamfer Cluster 0: [4.49829981 4.38844221]
# (8, 128, 128, 3)
# Group 64: Chamfer Cluster 1: [1.79139291 2.1935921 ]
# (39, 128, 128, 3)
# Group 64: Chamfer Cluster 2: [4.60995301 4.17999214]
# (2, 128, 128, 3)
# Group 64: Chamfer Cluster 3: [4.36019864 6.98516207]
# (1, 128, 128, 3)
# Group 64: Chamfer Cluster 4: [1.61681578 1.75064881]
# (5, 128, 128, 3)
# Group 120: Chamfer Cluster 0: [4.67859747 5.09722044]
# (26, 128, 128, 3)
# Group 120: Chamfer Cluster 1: [3.63238511 3.32333764]
# (1, 128, 128, 3)
# Group 120: Chamfer Cluster 2: [4.48245337 2.66423315]
# (4, 128, 128, 3)
# Group 120: Chamfer Cluster 3: [5.59210154 4.99820892]
# (1, 128, 128, 3)
# Group 120: Chamfer Cluster 4: [7.68443593 7.55117723]
# (1, 128, 128, 3)
# Group 128: Chamfer Cluster 0: [2.88342934 5.42370537]
# (16, 128, 128, 3)
# Group 128: Chamfer Cluster 1: [2.37318656 2.50845675]
# (27, 128, 128, 3)
# Group 128: Chamfer Cluster 2: [3.99607104 3.63046762]
# (9, 128, 128, 3)
# Group 128: Chamfer Cluster 3: [4.29391407 4.67822436]
# (4, 128, 128, 3)
# Group 128: Chamfer Cluster 4: [8.09545661 7.63865465]
